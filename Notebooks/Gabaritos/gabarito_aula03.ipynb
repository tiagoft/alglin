# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Parte 1

# %% [markdown]
# Exercicio 1

# %% [markdown]
# Exercicio 2

# %% [markdown]
# 1) x
# 2) y
# 3) Vermelho
# 4) Azul

# %% [markdown]
# Exercicio 3

# %%
A = np.array( [ [-5,1], [-2,1]])
y = np.array( [[3], [5]])
x = np.linalg.solve(A,y)
print(x)

# %% [markdown]
# Exercicio 4

# %% [markdown]
# Exercicio 5

# %% [markdown]
# 1) 3c + b = 17

# %%
c = np.linspace(0,10,3)
b = 17 - 3*c

plt.figure()
plt.plot(c, b) 
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# 2) 2c + b = 12

# %%
b2 = 12 - 2*c 

plt.figure()
plt.plot(c, b2) 
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# 3) A coxinha é 5 reais e o brigadeiro é 2 reais

# %%
c = np.linspace(0,10,3)
b = 17 - 3*c

b2 = 12 - 2*c

A = np.array([[3,1], [2,1]])
y = np.array([[17], [12]])

print(np.linalg.solve(A,y))
# coxinha é 5 reais e o brigadeiro é 2 reais


plt.figure()
plt.plot(c, b) 
plt.plot(c, b2) 
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# [[5.]
#  [2.]]

# %% [markdown]
# Exercicio 5

# %% [markdown]
# 1) D = 4

# %% [markdown]
# 2) Da erro, pois quando o determinante é zero não tem solução.

# %%
D = 4
A = np.array([[1, 2], [2, D]])
y = np.array([[3],[4]])
x = np.linalg.solve(A, y)
print(x)

# %% [markdown]
# 3) Não

# %% [markdown]
# Exercicio 7

# %% [markdown]
# Erro : LinAlgError: Singular matrix (matriz singular não tem inversa)

# %% [markdown]
# Exercicio 8

# %% [markdown]
# O determinante é diferente de zero, então em um plano 2D isso quer dizer que as retas se cruzam em um único ponto (se D=0 as retas são paralelas)

# %%
A = np.array([[4,5], [-6,1]])
y = np.array([[-3], [5]])
solucao = np.linalg.solve(A,y)
det = np.linalg.det(A)

print(solucao)
print(det)

# %% [markdown]
# ## Parte 2

# %% [markdown]
# Exercicio 1

# %% [markdown]
# 1) Area = 1

# %% [markdown]
# 2) A solução não é única, pois como são expansões uniformes se multiplicarmos apenas 0.5 por 8 também aumentaria a área em 4 vezes.

# %%
x = np.random.uniform(-0.5 * 4, 0.5 * 4, size=(2, 600))
plt.figure()
plt.scatter(x[0,:], x[1,:], s=1, c='r')
plt.xlim([-2, 2])
plt.ylim([-2, 2])
plt.grid()
plt.show()

# %% [markdown]
# Exercicio 2

# %% [markdown]
# 1)
#     - expansao no eixo y
#     - cisalhamento no eixo x
#     - cisalhamento no eixo y
#     - rotacao
#     - rotacao

# %% [markdown]
# Exercicio 3

# %% [markdown]
# 1)
#     - D = 1, determinante = 1
#     - D = 1.5, determinante = 1.5
#     - D = 2, determinante = 2
#     - D = 0, determinante = 0

# %%
x = np.random.uniform(-0.5, 0.5, size=(2, 600))
D = 1
A = np.array([ [1, 0], [0, D] ])
y = A @ x
print(np.linalg.det(A))
plt.figure()
plt.scatter(x[0,:], x[1,:], s=1, c='r')
plt.scatter(y[0,:], y[1,:], s=1, c='b')
plt.xlim([-2, 2])
plt.ylim([-2, 2])
plt.grid()
plt.show()
# Out:
# 1.0

# %% [markdown]
# 2) O determinante é o tamanho da expansão.

# %% [markdown]
# 3) Não tenho inversa, pois perco informação.

# %% [markdown]
# Exercicio 4

# %%
x = np.random.uniform(-0.5, 0.5, size=(2, 600))
A = np.array([ [0.25, 0], [0, 3] ])
B = np.array([ [0.7, -0.7], [0.7, 0.7] ])
y = B @ A @ x 
plt.figure()
plt.scatter(x[0,:], x[1,:], s=1, c='r')
plt.scatter(y[0,:], y[1,:], s=1, c='b')
plt.xlim([-2, 2])
plt.ylim([-2, 2])
plt.grid()
plt.show()

# %% [markdown]
# Exercicio 5

# %% [markdown]
# 1)

# %%
x = np.random.uniform(-0.5, 0.5, size=(2, 600))
delta_x = np.array([ [2.8], [0.005] ])
A = np.array( [[0.5, 0], [0, 1]]) # Compressao
B = np.array( [[0.7, -0.7], [0.7, 0.7]]) # Rotacao

y = B @ A @ (x + delta_x) 

plt.figure()
plt.scatter(x[0,:], x[1,:], s=1, c='r')
plt.scatter(y[0,:], y[1,:], s=1, c='b')
plt.xlim([-2, 2])
plt.ylim([-2, 2])
plt.grid()
plt.show()

# %% [markdown]
# 2) Sim

# %%
M = B @ A
print(M)

delta_x1 = 2.8
delta_x2 = 0.005

M = np.array([[0.35, -0.7, delta_x1], [0.35, 0.7, delta_x2], [0,0,1]])

print(M)
# Out:
# [[ 0.35 -0.7 ]
#  [ 0.35  0.7 ]]
# [[ 0.35  -0.7    2.8  ]
#  [ 0.35   0.7    0.005]
#  [ 0.     0.     1.   ]]

# %% [markdown]
# Exercicio 6

# %% [markdown]
# 2) A é matriz de translacao e B é a matriz de rotacao.

# %% [markdown]
# 3) Elas nao levam a resultados iguais, pois a ordem da multiplicacao matricial importa.

# %% [markdown]
# ## Parte 3

# %% [markdown]
# Exercicio 1

# %% [markdown]
# 1) Os eixos representam x, y e numero de canais de cor da imagem.
# 2) As dimensoes são (427, 640, 3)

# %% [markdown]
# Exercicio 2

# %% [markdown]
# 1)
#     - carrega imagem como array numpy
#     - cria uma imagem preta do mesmo tamanho
#     - devolve todos os pares do retangula de acordo com a coordenada
#     - copia posicao a posicao das coordenadas da primeira imagem na imagem preta

# %% [markdown]
# 2)

# %%
image = mpimg.imread("rio_de_janeiro.jpg")
image_ = np.zeros_like(image)

X = criar_indices(0, 300, 0, 640)
image_[X[0,:], X[1,:], :] = image[X[0,:], X[1,:], :]

print(image_.shape)
plt.figure()
plt.imshow(image_)
plt.show()

# %% [markdown]
# Exercicio 5

# %%
image = mpimg.imread("rio_de_janeiro.jpg")
image_ = np.zeros_like(image)

X = criar_indices(0, 300, 0, 300)
X = np.vstack ( (X, np.ones( X.shape[1]) ) )

A = np.array([[1, 0, 50], [0, 1, 50], [0, 0,1]])
Xd = A @ X
Xd = Xd.astype(int) 
X = X.astype(int)

print(Xd.shape)

image_[Xd[0,:], Xd[1,:], :] = image[X[0,:], X[1,:], :]

print(image_.shape)
plt.figure(figsize=(15,15))
plt.subplot(1,2,1)
plt.imshow(image)
# Adiciona o retângulo indicando a área que foi recortada:
plt.gca().add_patch(Rectangle((0,0),300,300,linewidth=5,edgecolor='r',facecolor='none'))

plt.title('Origem')
plt.subplot(1,2,2)
plt.imshow(image_)
plt.title('Destino')
plt.show()
